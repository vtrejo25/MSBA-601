# %% [markdown]
# # 📚 Free Dataset Sources for Use with Pandas
#
# ## 🧠 General Dataset Repositories
#
# 1. **[Kaggle Datasets](https://www.kaggle.com/datasets)**
#    - One of the largest collections of datasets across all topics.
#    - Requires a free account.
#    - You can use `pandas` to read CSV files after downloading or use Kaggle’s API.
#
# 2. **[Google Dataset Search](https://datasetsearch.research.google.com/)**
#    - A search engine for datasets across the web.
#    - Great for finding niche or domain-specific datasets.
#
# 3. **[UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php)**
#    - Classic datasets used for machine learning and statistics.
#    - Usually available in CSV or data format for easy import into pandas.
#
# ---
#
# ## 📊 Government & Open Data Portals
#
# 4. **[data.gov (USA)](https://www.data.gov/)**
#    - Datasets from various US government agencies.
#    - Covers topics like climate, education, energy, finance, and more.
#
# 5. **[EU Open Data Portal](https://data.europa.eu/en)**
#    - Datasets from the European Union institutions.
#
# 6. **[World Bank Open Data](https://data.worldbank.org/)**
#    - Economic, population, and development data from around the world.
#
# 7. **[UN Data](https://data.un.org/)**
#    - Statistics from various UN databases.
#
# ---
#
# ## 💻 Tech & Web Data
#
# 8. **[GitHub - Awesome Public Datasets](https://github.com/awesomedata/awesome-public-datasets)**
#    - Curated list of high-quality public datasets.
#
# 9. **[FiveThirtyEight](https://data.fivethirtyeight.com/)**
#    - Data behind their articles: politics, sports, economics, etc.
#    - Often formatted cleanly and ready for pandas.
#
# 10. **[IMDb Datasets](https://www.imdb.com/interfaces/)**
#    - Movie, TV, and celebrity data (requires a little processing).
#
# ---
#
# ## 🎓 Educational & Research
#
# 11. **[OpenML](https://www.openml.org/)**
#    - Open machine learning datasets with task metadata.
#
# 12. **[Harvard Dataverse](https://dataverse.harvard.edu/)**
#    - Academic and social science datasets.
#
# 13. **[CMU StatLib](http://lib.stat.cmu.edu/datasets/)**
#    - A small but reliable collection of classic statistics datasets.
#
# ---
#
# ## ✅ Read CSV in Pandas
#
# If the dataset is a `.csv` file:
#
# ```python
# import pandas as pd
#
# df = pd.read_csv('path_or_url_to_file.csv')
# print(df.head())
