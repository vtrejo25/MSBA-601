# %% [markdown]
# # Using Markdown Cells in VSCode Jupyter Notebooks to Teach a Class
# This notebook provides a structured guide on how to use Markdown cells effectively when teaching a class using Jupyter Notebooks in VSCode.

# %% [markdown]
# ## 1. Setting Up Your Jupyter Notebook in VSCode
# ### Step 1: Install Jupyter Extension
# - Open **VSCode**
# - Press `Ctrl + P` and type:
#   ```
#   ext install ms-toolsai.jupyter
#   ```
# - Install the **Jupyter** extension.

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas
#
# File ~/Documents/GitHub/MSBA-601/venv/lib/python3.13/site-packages/pandas/__init__.py:14
#      12 for _dependency in _hard_dependencies:
#      13     try:
# ---> 14         __import__(_dependency)
#      15     except ImportError as _e:  # pragma: no cover
#      16         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File ~/Documents/GitHub/MSBA-601/venv/lib/python3.13/site-packages/numpy/__init__.py:114
#     111 from . import _distributor_init
#     113 try:
# --> 114     from numpy.__config__ import show_config
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
#
# File ~/Documents/GitHub/MSBA-601/venv/lib/python3.13/site-packages/numpy/__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show_config"]
#      11 _built_with_meson = True
#
# File ~/Documents/GitHub/MSBA-601/venv/lib/python3.13/site-packages/numpy/_core/__init__.py:23
#      20         env_added.append(envkey)
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#      25     import sys
#
# File ~/Documents/GitHub/MSBA-601/venv/lib/python3.13/site-packages/numpy/_core/multiarray.py:10
#       1 """
#       2 Create the numpy._core.multiarray namespace for backward compatibility.
#       3 In v1.16 the multiarray and umath c-extension modules were merged into
#    (...)
#       6
#       7 """
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#      12 from ._multiarray_umath import *  # noqa: F403
#
# File ~/Documents/GitHub/MSBA-601/venv/lib/python3.13/site-packages/numpy/_core/overrides.py:7
#       5 from .._utils import set_module
#       6 from .._utils._inspect import getargspec
# ----> 7 from numpy._core._multiarray_umath import (
#       8     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      11 ARRAY_FUNCTIONS = set()
#      13 array_function_like_doc = (
#      14     """like : array_like, optional
#      15         Reference object to allow the creation of arrays which are not
#    (...)
#      19         compatible with that passed in via this argument."""
#      20 )
#
# RuntimeError: CPU dispatcher tracer already initlized

# %% [markdown]
# ### Step 2: Open or Create a Jupyter Notebook
# - Open **Command Palette** (`Ctrl + Shift + P` / `Cmd + Shift + P` on Mac)
# - Search **"Jupyter: Create New Blank Notebook"**
# - Alternatively, open an existing `.ipynb` file.

# %% [markdown]
# ### Step 3: Add a Markdown Cell
# - Click **+** (Add Cell) in the notebook toolbar.
# - Change the cell type from **Code** to **Markdown** in the dropdown.

# %% [markdown]
# ## 2. Markdown Basics for Teaching
# ### Headings (Titles & Sections)
# Use `#` for headings to structure your content:

# %% [markdown]
# # Main Title (H1)
# ## Section Title (H2)
# ### Subsection Title (H3)
# #### Smaller Subsection (H4)

# %% [markdown]
# ### Bold & Italics

# %% [markdown]
# **Bold Text**
# *Italic Text*

# %% [markdown]
# ### Lists (Bullet & Numbered)
# #### Unordered List (Bullets)

# %% [markdown]
# - Python
# - Pandas
# - NumPy

# %% [markdown]
# #### Ordered List (Numbers)

# %% [markdown]
# 1. Open VSCode
# 2. Install Jupyter Extension
# 3. Create a Notebook

# %% [markdown]
# ## 3. Adding Code Blocks
# To display code without execution, use triple backticks (```) or indent with 4 spaces:

# %% [markdown]
# ```python
# import pandas as pd
# df = pd.read_csv("data.csv")
# df.head()
# ```

# %% [markdown]
# ## 4. Adding Images
# To insert an image, use:

# %% [markdown]
# <img src="https://pandas.pydata.org/static/img/pandas_mark.svg" width="200"/>

# %% [markdown]
# ## 5. Adding Equations (LaTeX Support)
# Mathematical equations can be written using LaTeX inside `$...$` for inline math or `$$...$$` for block equations.

# %% [markdown]
# The area of a circle is given by $A = \pi r^2$.

# %% [markdown]
# ## 6. Creating Tables
# Tables can be created using `|` and `-`:

# %% [markdown]
# | Name  | Age | Grade |
# |-------|-----|-------|
# | Alice |  24 |   A   |
# | Bob   |  22 |   B   |

# %% [markdown]
# ## 7. Adding Interactive Links
# You can add links for external references:

# %% [markdown]
# [Visit Pandas Documentation](https://pandas.pydata.org/docs/)

# %% [markdown]
# ## 8. Best Practices for Teaching with Markdown in VSCode
# - **Use Headings** for clear structure.
# - **Add Images & Equations** where necessary.
# - **Use Lists** for easy-to-follow steps.
# - **Keep Code Blocks Separate** from explanations.
# - **Use Tables** to summarize data.
# - **Include Hyperlinks** for additional reading.

# %%
import pandas

# %% [markdown]
# With these Markdown techniques, you can create **well-structured, visually appealing, and interactive** Jupyter Notebooks to teach effectively using VSCode! 🚀
